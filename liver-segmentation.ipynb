# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install matplotlib
# numpy
# tqdm
# glob2
# !pip install dicom2nifti

# !pip install pytest-shutil
# !pip install nibabel
# !pip install monai
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy<2,>=1.20 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.20->matplotlib) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.20->matplotlib) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2,>=1.20->matplotlib) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2,>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2,>=1.20->matplotlib) (2024.2.0)
# Collecting pytest-shutil
#   Downloading pytest_shutil-1.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pytest-shutil) (1.17.0)
# Collecting execnet (from pytest-shutil)
#   Downloading execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from pytest-shutil) (8.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from pytest-shutil) (2.5.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->pytest-shutil) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pytest->pytest-shutil) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->pytest-shutil) (1.5.0)
# Downloading pytest_shutil-1.8.1-py3-none-any.whl (15 kB)
# Downloading execnet-2.1.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: execnet, pytest-shutil
# Successfully installed execnet-2.1.1 pytest-shutil-1.8.1
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel) (4.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22->nibabel) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22->nibabel) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22->nibabel) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22->nibabel) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22->nibabel) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22->nibabel) (2024.2.0)
# Collecting monai
#   Downloading monai-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.24 in /usr/local/lib/python3.11/dist-packages (from monai) (1.26.4)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.11/dist-packages (from monai) (2.5.1+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.0,>=1.24->monai) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.9->monai)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.9->monai)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.9->monai)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.9->monai)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.9->monai)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.9->monai)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.9->monai)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9->monai) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.0,>=1.24->monai) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.0,>=1.24->monai) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.0,>=1.24->monai) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.0,>=1.24->monai) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.0,>=1.24->monai) (2024.2.0)
# Downloading monai-1.4.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.0 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, monai
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed monai-1.4.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install -q torch torchvision

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"PyTorch is installed and CUDA is available! Using device: {device}")
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print(f"PyTorch is installed, but CUDA is not available. Using CPU: {device}")

print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch is installed and CUDA is available! Using device: cuda
# CUDA device name: Tesla P100-PCIE-16GB
# PyTorch version: 2.5.1+cu124

# %%
# !ls /kaggle/input

# %%
import sys
print(sys.version)

# %%
# !ls /kaggle/input/liver-tumor-segmentation

# %% [markdown]
# Date : 29-04-2025

# %%
# !pip install pytest-shutil
# !pip install glob2

# %%
# !python -m pip install --upgrade pip

# %%
# !pip install pytest-shutil

# %%
# !git clone https://github.com/oncowonyoungcho/nii2dcm.git

# %%
# !pwd

# %%
# !cd /kaggle/working/nii2dcm
# !pwd  # Optional: Print the current working directory to verify the change

# %%
# !pwd

# %%
# !pip install setuptools wheel

# %%
# !ls

# %%
# !pip install -r requirements.txt

# %%
# !pwd

# %%
# !pip install -r requirements.txt

# %%
# !pip install -e .

# %%
import os as os

# %%
os.getcwd()

# %%
# input_path = '/kaggle/input/liver-tumor-segmentation/volume_pt1'
# output_path = '/kaggle/working/dicom_files' 
# convert_nii_to_dicom(input_path ,output_path)
# print('done')

# %%
# input_path = '/kaggle/input/liver-tumor-segmentation-part-2/'
# output_path = '/kaggle/working/dicom_files' 

# convert_subdirs_to_dicom(input_path,output_path)

# %%
# root_dir = '/kaggle/working/dicom_files'
# print_batch_analysis(root_dir)

# %%
# !ls

# %%
# !pwd

# %%
# !ls

# %% [markdown]
# New Preprocess

# %%
import os
from glob import glob
import random
from monai.transforms import (
    Compose,
    EnsureChannelFirstD,
    LoadImaged,
    Resized,
    ToTensord,
    Spacingd,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
)
from monai.data import DataLoader, Dataset, CacheDataset
from monai.utils import set_determinism


def prepare(in_dir, pixdim=(1.5, 1.5, 1.0), a_min=-200, a_max=200, spatial_size=[128, 128, 64], cache=True):
    """
    This function handles data preprocessing directly from the source directory.
    Args:
        in_dir: Input directory containing images and labels
        pixdim: Target pixel dimensions for resampling
        a_min: Minimum intensity value for scaling
        a_max: Maximum intensity value for scaling
        spatial_size: Target spatial size for resizing
        cache: Whether to cache the dataset
    """
    set_determinism(seed=0)
    random.seed(42)
    image_path = '/kaggle/input/liver-segmentation-preprocessed/images\ \(2\)/images/*.nii.gz'
    finalPath = os.path.join(in_dir, 'images\ \(2\)','images', '*')
    print(finalPath)
    # Get all image and label files
    image_files = sorted(glob(os.path.join(in_dir, r'images (2)','images', '*')))
    # image_files = sorted(glob(finalPath))
    print(len(image_files))
    label_files = sorted(glob(os.path.join(in_dir, r'labels (2)','labels', '*')))
    print(len(label_files))

    # Create pairs of image and label files
    file_pairs = list(zip(image_files, label_files))
    random.shuffle(file_pairs)

    # Calculate split index for 80/20 split
    split_idx = int(len(file_pairs) * 0.8)

    # Split into train and test
    train_pairs = file_pairs[:split_idx]
    test_pairs = file_pairs[split_idx:]

    # Create data dictionaries for train and test
    train_files = [{"vol": img_path, "seg": label_path} for img_path, label_path in train_pairs]
    test_files = [{"vol": img_path, "seg": label_path} for img_path, label_path in test_pairs]

    train_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            EnsureChannelFirstD(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True),
            CropForegroundd(keys=["vol", "seg"], source_key="vol"),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),
            ToTensord(keys=["vol", "seg"]),
        ]
    )

    test_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            EnsureChannelFirstD(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True),
            CropForegroundd(keys=['vol', 'seg'], source_key='vol'),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),
            ToTensord(keys=["vol", "seg"]),
        ]
    )

    if cache:
        train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = CacheDataset(data=test_files, transform=test_transforms, cache_rate=1.0)
        test_loader = DataLoader(test_ds, batch_size=1)

        return train_loader, test_loader

    else:
        train_ds = Dataset(data=train_files, transform=train_transforms)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = Dataset(data=test_files, transform=test_transforms)
        test_loader = DataLoader(test_ds, batch_size=1)

        return train_loader, test_loader

# if __name__ == "__main__":
#     # Example usage
#     train_loader, test_loader = prepare('/kaggle/input/liver-segmentation-preprocessed')
#     print("Data preprocessing completed!")
#     print(f"Number of training samples: {len(train_loader)}")
#     print(f"Number of test samples: {len(test_loader)}")
# Out:
# 2025-05-01 06:51:51.560169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746082311.749990      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746082311.809649      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_loader, test_loader = prepare('/kaggle/input/liver-segmentation-preprocessed/')
# Out:
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)
# /kaggle/input/liver-segmentation-preprocessed/images\ \(2\)/images/*
# 544
# 544
# Loading dataset: 100%|██████████| 435/435 [18:56<00:00,  2.61s/it]
# Loading dataset: 100%|██████████| 109/109 [04:47<00:00,  2.64s/it]

# %%
import torch
import pickle

# Assuming your dataset is custom or from torchvision
train_dataset = train_loader.dataset
test_dataset = test_loader.dataset

# Save dataset to a file
with open("train_dataset_liver.pkl", "wb") as f:
    pickle.dump(train_dataset, f)

with open("test_dataset_liver.pkl", "wb") as f:
    pickle.dump(test_dataset, f)

# %%
import torch
import pickle

# %%
in_dir = '/kaggle/input/liver-segmentation-preprocessed/'
image_files = sorted(glob(os.path.join(in_dir,  r'images (2)','images', '*')))
len(image_files)
# Out:
# 544

# %%
# Out:
# /kaggle/working

# %%
# !ls /kaggle/input/liver-segmentation-preprocessed/images (2)/images/
# !ls /kaggle/input/liver-segmentation-preprocessed/images\ \(2\)/images/*

# %%
train_loader

# %%
len(train_loader.dataset)
# Out:
# 0

# %%
from monai.utils import first
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from monai.losses import DiceLoss
from tqdm import tqdm

def dice_metric(predicted, target):
    '''
    In this function we take `predicted` and `target` (label) to calculate the dice coeficient then we use it 
    to calculate a metric value for the training and the validation.
    '''
    dice_value = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
    value = 1 - dice_value(predicted, target).item()
    return value

def calculate_weights(val1, val2):
    '''
    In this function we take the number of the background and the forgroud pixels to return the `weights` 
    for the cross entropy loss values.
    '''
    count = np.array([val1, val2])
    summ = count.sum()
    weights = count/summ
    weights = 1/weights
    summ = weights.sum()
    weights = weights/summ
    return torch.tensor(weights, dtype=torch.float32)

def train(model, data_in, loss, optim, max_epochs, model_dir, test_interval=1 , device=torch.device("cuda")):
    best_metric = -1
    best_metric_epoch = -1
    save_loss_train = []
    save_loss_test = []
    save_metric_train = []
    save_metric_test = []
    train_loader, test_loader = data_in

    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        train_epoch_loss = 0
        train_step = 0
        epoch_metric_train = 0
        for batch_data in train_loader:
            
            train_step += 1

            volume = batch_data["vol"]
            label = batch_data["seg"]
            label = label != 0
            volume, label = (volume.to(device), label.to(device))

            optim.zero_grad()
            outputs = model(volume)
            
            train_loss = loss(outputs, label)
            
            train_loss.backward()
            optim.step()

            train_epoch_loss += train_loss.item()
            print(
                f"{train_step}/{len(train_loader) // train_loader.batch_size}, "
                f"Train_loss: {train_loss.item():.4f}")

            train_metric = dice_metric(outputs, label)
            epoch_metric_train += train_metric
            print(f'Train_dice: {train_metric:.4f}')

        print('-'*20)
        
        train_epoch_loss /= train_step
        print(f'Epoch_loss: {train_epoch_loss:.4f}')
        save_loss_train.append(train_epoch_loss)
        np.save(os.path.join(model_dir, 'loss_train.npy'), save_loss_train)
        
        epoch_metric_train /= train_step
        print(f'Epoch_metric: {epoch_metric_train:.4f}')

        save_metric_train.append(epoch_metric_train)
        np.save(os.path.join(model_dir, 'metric_train.npy'), save_metric_train)

        if (epoch + 1) % test_interval == 0:

            model.eval()
            with torch.no_grad():
                test_epoch_loss = 0
                test_metric = 0
                epoch_metric_test = 0
                test_step = 0

                for test_data in test_loader:

                    test_step += 1

                    test_volume = test_data["vol"]
                    test_label = test_data["seg"]
                    test_label = test_label != 0
                    test_volume, test_label = (test_volume.to(device), test_label.to(device),)
                    
                    test_outputs = model(test_volume)
                    
                    test_loss = loss(test_outputs, test_label)
                    test_epoch_loss += test_loss.item()
                    test_metric = dice_metric(test_outputs, test_label)
                    epoch_metric_test += test_metric
                    
                
                test_epoch_loss /= test_step
                print(f'test_loss_epoch: {test_epoch_loss:.4f}')
                save_loss_test.append(test_epoch_loss)
                np.save(os.path.join(model_dir, 'loss_test.npy'), save_loss_test)

                epoch_metric_test /= test_step
                print(f'test_dice_epoch: {epoch_metric_test:.4f}')
                save_metric_test.append(epoch_metric_test)
                np.save(os.path.join(model_dir, 'metric_test.npy'), save_metric_test)

                if epoch_metric_test > best_metric:
                    best_metric = epoch_metric_test
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(
                        model_dir, "best_metric_model.pth"))
                
                print(
                    f"current epoch: {epoch + 1} current mean dice: {test_metric:.4f}"
                    f"\nbest mean dice: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )


    print(
        f"train completed, best_metric: {best_metric:.4f} "
        f"at epoch: {best_metric_epoch}")


def show_patient(data, SLICE_NUMBER=1, train=True, test=False):
    """
    This function is to show one patient from your datasets, so that you can si if the it is okay or you need 
    to change/delete something.

    `data`: this parameter should take the patients from the data loader, which means you need to can the function
    prepare first and apply the transforms that you want after that pass it to this function so that you visualize 
    the patient with the transforms that you want.
    `SLICE_NUMBER`: this parameter will take the slice number that you want to display/show
    `train`: this parameter is to say that you want to display a patient from the training data (by default it is true)
    `test`: this parameter is to say that you want to display a patient from the testing patients.
    """

    check_patient_train, check_patient_test = data

    view_train_patient = first(check_patient_train)
    view_test_patient = first(check_patient_test)

    
    if train:
        plt.figure("Visualization Train", (12, 6))
        plt.subplot(1, 2, 1)
        plt.title(f"vol {SLICE_NUMBER}")
        plt.imshow(view_train_patient["vol"][0, 0, :, :, SLICE_NUMBER], cmap="gray")

        plt.subplot(1, 2, 2)
        plt.title(f"seg {SLICE_NUMBER}")
        plt.imshow(view_train_patient["seg"][0, 0, :, :, SLICE_NUMBER])
        plt.show()
    
    if test:
        plt.figure("Visualization Test", (12, 6))
        plt.subplot(1, 2, 1)
        plt.title(f"vol {SLICE_NUMBER}")
        plt.imshow(view_test_patient["vol"][0, 0, :, :, SLICE_NUMBER], cmap="gray")

        plt.subplot(1, 2, 2)
        plt.title(f"seg {SLICE_NUMBER}")
        plt.imshow(view_test_patient["seg"][0, 0, :, :, SLICE_NUMBER])
        plt.show()


def calculate_pixels(data):
    val = np.zeros((1, 2))

    for batch in tqdm(data):
        batch_label = batch["seg"] != 0
        _, count = np.unique(batch_label, return_counts=True)

        if len(count) == 1:
            count = np.append(count, 0)
        val += count

    print('The last values:', val)
    return val

# %%
with open("train_dataset_liver.pkl", "rb") as f:
    train_dataset = pickle.load(f)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

with open("test_dataset_liver.pkl", "rb") as f:
    test_dataset = pickle.load(f)

test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
data_in = [train_loader,test_loader]

# %%
if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("Current CUDA device:", torch.cuda.current_device())
    print("CUDA device name:", torch.cuda.get_device_name(0))
# Out:
# CUDA device count: 1
# Current CUDA device: 0
# CUDA device name: Tesla P100-PCIE-16GB

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.losses import DiceLoss, DiceCELoss

import torch
# from preporcess import prepare
# from utilities import train


# data_dir = 'D:/Youtube/Organ and Tumor Segmentation/datasets/Task03_Liver/Data_Train_Test'
# data_dir = 'D:/Aayush Dataset/nifti_files'
# model_dir = 'D:/Youtube/Organ and Tumor Segmentation/results/results' 
model_dir = '/kaggle/working/results'
# data_in = prepare(data_dir, cache=True)

device = torch.device("cuda:0")
# device = torch.device("cpu")
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256), 
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)


#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)


train(model, data_in, loss_function, optimizer, 600, model_dir)
# Out:
# ----------
# epoch 1/600
# 1/0, Train_loss: 0.5481
# Train_dice: 0.4519
# 2/0, Train_loss: 0.5461
# Train_dice: 0.4539
# 3/0, Train_loss: 0.5463
# Train_dice: 0.4537
# 4/0, Train_loss: 0.5462
# Train_dice: 0.4538
# 5/0, Train_loss: 0.5429
# Train_dice: 0.4571
# 6/0, Train_loss: 0.5424
# Train_dice: 0.4576
# 7/0, Train_loss: 0.5461
# Train_dice: 0.4539
# 8/0, Train_loss: 0.5440
# Train_dice: 0.4560
# 9/0, Train_loss: 0.5460
# Train_dice: 0.4540
# 10/0, Train_loss: 0.5452
# Train_dice: 0.4548
# 11/0, Train_loss: 0.5427
# Train_dice: 0.4573
# 12/0, Train_loss: 0.5449
# Train_dice: 0.4551
# 13/0, Train_loss: 0.5431
# Train_dice: 0.4569
# 14/0, Train_loss: 0.5470
# Train_dice: 0.4530
# --------------------
# Epoch_loss: 0.5451
# Epoch_metric: 0.4549
# test_loss_epoch: 0.5680
# test_dice_epoch: 0.4320
# current epoch: 1 current mean dice: 0.4372
# best mean dice: 0.4320 at epoch: 1
# ----------
# epoch 2/600
# 1/0, Train_loss: 0.5374
# Train_dice: 0.4626
# 2/0, Train_loss: 0.5436
# Train_dice: 0.4564
# 3/0, Train_loss: 0.5441
# Train_dice: 0.4559
# 4/0, Train_loss: 0.5413
# Train_dice: 0.4587
# 5/0, Train_loss: 0.5450
# Train_dice: 0.4550
# 6/0, Train_loss: 0.5453
# Train_dice: 0.4547
# 7/0, Train_loss: 0.5454
# Train_dice: 0.4546
# 8/0, Train_loss: 0.5418
# Train_dice: 0.4582
# 9/0, Train_loss: 0.5447
# Train_dice: 0.4553
# 10/0, Train_loss: 0.5430
# Train_dice: 0.4570
# 11/0, Train_loss: 0.5433
# Train_dice: 0.4567
# 12/0, Train_loss: 0.5451
# Train_dice: 0.4549
# 13/0, Train_loss: 0.5456
# Train_dice: 0.4544
# 14/0, Train_loss: 0.5454
# Train_dice: 0.4546
# --------------------
# Epoch_loss: 0.5437
# Epoch_metric: 0.4563
# test_loss_epoch: 0.5554
# test_dice_epoch: 0.4446
# current epoch: 2 current mean dice: 0.4433
# best mean dice: 0.4446 at epoch: 2
# ----------
# epoch 3/600
# 1/0, Train_loss: 0.5444
# Train_dice: 0.4556
# 2/0, Train_loss: 0.5432
# Train_dice: 0.4568
# 3/0, Train_loss: 0.5443
# Train_dice: 0.4557
# 4/0, Train_loss: 0.5447
# Train_dice: 0.4553
# 5/0, Train_loss: 0.5435
# Train_dice: 0.4565
# 6/0, Train_loss: 0.5387
# Train_dice: 0.4613
# 7/0, Train_loss: 0.5407
# Train_dice: 0.4593
# 8/0, Train_loss: 0.5422
# Train_dice: 0.4578
# 9/0, Train_loss: 0.5417
# Train_dice: 0.4583
# 10/0, Train_loss: 0.5412
# Train_dice: 0.4588
# 11/0, Train_loss: 0.5446
# Train_dice: 0.4554
# 12/0, Train_loss: 0.5436
# Train_dice: 0.4564
# 13/0, Train_loss: 0.5367
# Train_dice: 0.4633
# 14/0, Train_loss: 0.5446
# Train_dice: 0.4554
# --------------------
# Epoch_loss: 0.5424
# Epoch_metric: 0.4576
# test_loss_epoch: 0.5438
# test_dice_epoch: 0.4562
# current epoch: 3 current mean dice: 0.4572
# best mean dice: 0.4562 at epoch: 3
# ----------
# epoch 4/600
# 1/0, Train_loss: 0.5398
# Train_dice: 0.4602
# 2/0, Train_loss: 0.5382
# Train_dice: 0.4618
# 3/0, Train_loss: 0.5408
# Train_dice: 0.4592
# 4/0, Train_loss: 0.5404
# Train_dice: 0.4596
# 5/0, Train_loss: 0.5415
# Train_dice: 0.4585
# 6/0, Train_loss: 0.5432
# Train_dice: 0.4568
# 7/0, Train_loss: 0.5426
# Train_dice: 0.4574
# 8/0, Train_loss: 0.5387
# Train_dice: 0.4613
# 9/0, Train_loss: 0.5430
# Train_dice: 0.4570
# 10/0, Train_loss: 0.5430
# Train_dice: 0.4570
# 11/0, Train_loss: 0.5394
# Train_dice: 0.4606
# 12/0, Train_loss: 0.5407
# Train_dice: 0.4593
# 13/0, Train_loss: 0.5436
# Train_dice: 0.4564
# 14/0, Train_loss: 0.5434
# Train_dice: 0.4566
# --------------------
# Epoch_loss: 0.5413
# Epoch_metric: 0.4587
# test_loss_epoch: 0.5408
# test_dice_epoch: 0.4592
# current epoch: 4 current mean dice: 0.4581
# best mean dice: 0.4592 at epoch: 4
# ----------
# epoch 5/600
# 1/0, Train_loss: 0.5405
# Train_dice: 0.4595
# 2/0, Train_loss: 0.5390
# Train_dice: 0.4610
# 3/0, Train_loss: 0.5422
# Train_dice: 0.4578
# 4/0, Train_loss: 0.5415
# Train_dice: 0.4585
# 5/0, Train_loss: 0.5425
# Train_dice: 0.4575
# 6/0, Train_loss: 0.5384
# Train_dice: 0.4616
# 7/0, Train_loss: 0.5407
# Train_dice: 0.4593
# 8/0, Train_loss: 0.5428
# Train_dice: 0.4572
# 9/0, Train_loss: 0.5415
# Train_dice: 0.4585
# 10/0, Train_loss: 0.5401
# Train_dice: 0.4599
# 11/0, Train_loss: 0.5401
# Train_dice: 0.4599
# 12/0, Train_loss: 0.5351
# Train_dice: 0.4649
# 13/0, Train_loss: 0.5383
# Train_dice: 0.4617
# 14/0, Train_loss: 0.5402
# Train_dice: 0.4598
# --------------------
# Epoch_loss: 0.5402
# Epoch_metric: 0.4598
# test_loss_epoch: 0.5399
# test_dice_epoch: 0.4601
# current epoch: 5 current mean dice: 0.4588
# best mean dice: 0.4601 at epoch: 5
# ----------
# epoch 6/600
# 1/0, Train_loss: 0.5399
# Train_dice: 0.4601
# 2/0, Train_loss: 0.5398
# Train_dice: 0.4602
# 3/0, Train_loss: 0.5422
# Train_dice: 0.4578
# 4/0, Train_loss: 0.5397
# Train_dice: 0.4603
# 5/0, Train_loss: 0.5401
# Train_dice: 0.4599
# 6/0, Train_loss: 0.5352
# Train_dice: 0.4648
# 7/0, Train_loss: 0.5402
# Train_dice: 0.4598
# 8/0, Train_loss: 0.5387
# Train_dice: 0.4613
# 9/0, Train_loss: 0.5414
# Train_dice: 0.4586
# 10/0, Train_loss: 0.5328
# Train_dice: 0.4672
# 11/0, Train_loss: 0.5407
# Train_dice: 0.4593
# 12/0, Train_loss: 0.5376
# Train_dice: 0.4624
# 13/0, Train_loss: 0.5404
# Train_dice: 0.4596
# 14/0, Train_loss: 0.5414
# Train_dice: 0.4586
# --------------------
# Epoch_loss: 0.5393
# Epoch_metric: 0.4607
# test_loss_epoch: 0.5393
# test_dice_epoch: 0.4607
# current epoch: 6 current mean dice: 0.4598
# best mean dice: 0.4607 at epoch: 6
# ----------
# epoch 7/600
# 1/0, Train_loss: 0.5355
# Train_dice: 0.4645
# 2/0, Train_loss: 0.5383
# Train_dice: 0.4617
# 3/0, Train_loss: 0.5387
# Train_dice: 0.4613
# 4/0, Train_loss: 0.5413
# Train_dice: 0.4587
# 5/0, Train_loss: 0.5352
# Train_dice: 0.4648
# 6/0, Train_loss: 0.5386
# Train_dice: 0.4614
# 7/0, Train_loss: 0.5378
# Train_dice: 0.4622
# 8/0, Train_loss: 0.5383
# Train_dice: 0.4617
# 9/0, Train_loss: 0.5396
# Train_dice: 0.4604
# 10/0, Train_loss: 0.5408
# Train_dice: 0.4592
# 11/0, Train_loss: 0.5397
# Train_dice: 0.4603
# 12/0, Train_loss: 0.5384
# Train_dice: 0.4616
# 13/0, Train_loss: 0.5377
# Train_dice: 0.4623
# 14/0, Train_loss: 0.5358
# Train_dice: 0.4642
# --------------------
# Epoch_loss: 0.5383
# Epoch_metric: 0.4617
# test_loss_epoch: 0.5384
# test_dice_epoch: 0.4616
# current epoch: 7 current mean dice: 0.4623
# best mean dice: 0.4616 at epoch: 7
# ----------
# epoch 8/600
# 1/0, Train_loss: 0.5405
# Train_dice: 0.4595
# 2/0, Train_loss: 0.5384
# Train_dice: 0.4616
# 3/0, Train_loss: 0.5380
# Train_dice: 0.4620
# 4/0, Train_loss: 0.5366
# Train_dice: 0.4634
# 5/0, Train_loss: 0.5375
# Train_dice: 0.4625
# 6/0, Train_loss: 0.5403
# Train_dice: 0.4597
# 7/0, Train_loss: 0.5372
# Train_dice: 0.4628
# 8/0, Train_loss: 0.5387
# Train_dice: 0.4613
# 9/0, Train_loss: 0.5353
# Train_dice: 0.4647
# 10/0, Train_loss: 0.5338
# Train_dice: 0.4662
# 11/0, Train_loss: 0.5363
# Train_dice: 0.4637
# 12/0, Train_loss: 0.5380
# Train_dice: 0.4620
# 13/0, Train_loss: 0.5366
# Train_dice: 0.4634
# 14/0, Train_loss: 0.5374
# Train_dice: 0.4626
# --------------------
# Epoch_loss: 0.5375
# Epoch_metric: 0.4625
# test_loss_epoch: 0.5381
# test_dice_epoch: 0.4619
# current epoch: 8 current mean dice: 0.4608
# best mean dice: 0.4619 at epoch: 8
# ----------
# epoch 9/600
# 1/0, Train_loss: 0.5379
# Train_dice: 0.4621
# 2/0, Train_loss: 0.5385
# Train_dice: 0.4615
# 3/0, Train_loss: 0.5369
# Train_dice: 0.4631
# 4/0, Train_loss: 0.5396
# Train_dice: 0.4604
# 5/0, Train_loss: 0.5395
# Train_dice: 0.4605
# 6/0, Train_loss: 0.5385
# Train_dice: 0.4615
# 7/0, Train_loss: 0.5334
# Train_dice: 0.4666
# 8/0, Train_loss: 0.5343
# Train_dice: 0.4657
# 9/0, Train_loss: 0.5349
# Train_dice: 0.4651
# 10/0, Train_loss: 0.5364
# Train_dice: 0.4636
# 11/0, Train_loss: 0.5376
# Train_dice: 0.4624
# 12/0, Train_loss: 0.5356
# Train_dice: 0.4644
# 13/0, Train_loss: 0.5359
# Train_dice: 0.4641
# 14/0, Train_loss: 0.5333
# Train_dice: 0.4667
# --------------------
# Epoch_loss: 0.5366
# Epoch_metric: 0.4634
# test_loss_epoch: 0.5376
# test_dice_epoch: 0.4624
# current epoch: 9 current mean dice: 0.4611
# best mean dice: 0.4624 at epoch: 9
# ----------
# epoch 10/600
# 1/0, Train_loss: 0.5366
# Train_dice: 0.4634
# 2/0, Train_loss: 0.5359
# Train_dice: 0.4641
# 3/0, Train_loss: 0.5382
# Train_dice: 0.4618
# 4/0, Train_loss: 0.5368
# Train_dice: 0.4632
# 5/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 6/0, Train_loss: 0.5367
# Train_dice: 0.4633
# 7/0, Train_loss: 0.5357
# Train_dice: 0.4643
# 8/0, Train_loss: 0.5386
# Train_dice: 0.4614
# 9/0, Train_loss: 0.5315
# Train_dice: 0.4685
# 10/0, Train_loss: 0.5372
# Train_dice: 0.4628
# 11/0, Train_loss: 0.5338
# Train_dice: 0.4662
# 12/0, Train_loss: 0.5362
# Train_dice: 0.4638
# 13/0, Train_loss: 0.5360
# Train_dice: 0.4640
# 14/0, Train_loss: 0.5376
# Train_dice: 0.4624
# --------------------
# Epoch_loss: 0.5360
# Epoch_metric: 0.4640
# test_loss_epoch: 0.5365
# test_dice_epoch: 0.4635
# current epoch: 10 current mean dice: 0.4642
# best mean dice: 0.4635 at epoch: 10
# ----------
# epoch 11/600
# 1/0, Train_loss: 0.5372
# Train_dice: 0.4628
# 2/0, Train_loss: 0.5361
# Train_dice: 0.4639
# 3/0, Train_loss: 0.5348
# Train_dice: 0.4652
# 4/0, Train_loss: 0.5364
# Train_dice: 0.4636
# 5/0, Train_loss: 0.5340
# Train_dice: 0.4660
# 6/0, Train_loss: 0.5374
# Train_dice: 0.4626
# 7/0, Train_loss: 0.5345
# Train_dice: 0.4655
# 8/0, Train_loss: 0.5357
# Train_dice: 0.4643
# 9/0, Train_loss: 0.5341
# Train_dice: 0.4659
# 10/0, Train_loss: 0.5361
# Train_dice: 0.4639
# 11/0, Train_loss: 0.5318
# Train_dice: 0.4682
# 12/0, Train_loss: 0.5343
# Train_dice: 0.4657
# 13/0, Train_loss: 0.5348
# Train_dice: 0.4652
# 14/0, Train_loss: 0.5375
# Train_dice: 0.4625
# --------------------
# Epoch_loss: 0.5353
# Epoch_metric: 0.4647
# test_loss_epoch: 0.5364
# test_dice_epoch: 0.4636
# current epoch: 11 current mean dice: 0.4623
# best mean dice: 0.4636 at epoch: 11
# ----------
# epoch 12/600
# 1/0, Train_loss: 0.5346
# Train_dice: 0.4654
# 2/0, Train_loss: 0.5370
# Train_dice: 0.4630
# 3/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 4/0, Train_loss: 0.5334
# Train_dice: 0.4666
# 5/0, Train_loss: 0.5373
# Train_dice: 0.4627
# 6/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 7/0, Train_loss: 0.5325
# Train_dice: 0.4675
# 8/0, Train_loss: 0.5346
# Train_dice: 0.4654
# 9/0, Train_loss: 0.5368
# Train_dice: 0.4632
# 10/0, Train_loss: 0.5360
# Train_dice: 0.4640
# 11/0, Train_loss: 0.5348
# Train_dice: 0.4652
# 12/0, Train_loss: 0.5348
# Train_dice: 0.4652
# 13/0, Train_loss: 0.5370
# Train_dice: 0.4630
# 14/0, Train_loss: 0.5370
# Train_dice: 0.4630
# --------------------
# Epoch_loss: 0.5347
# Epoch_metric: 0.4653
# test_loss_epoch: 0.5358
# test_dice_epoch: 0.4642
# current epoch: 12 current mean dice: 0.4632
# best mean dice: 0.4642 at epoch: 12
# ----------
# epoch 13/600
# 1/0, Train_loss: 0.5370
# Train_dice: 0.4630
# 2/0, Train_loss: 0.5345
# Train_dice: 0.4655
# 3/0, Train_loss: 0.5345
# Train_dice: 0.4655
# 4/0, Train_loss: 0.5368
# Train_dice: 0.4632
# 5/0, Train_loss: 0.5369
# Train_dice: 0.4631
# 6/0, Train_loss: 0.5323
# Train_dice: 0.4677
# 7/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 8/0, Train_loss: 0.5358
# Train_dice: 0.4642
# 9/0, Train_loss: 0.5327
# Train_dice: 0.4673
# 10/0, Train_loss: 0.5360
# Train_dice: 0.4640
# 11/0, Train_loss: 0.5326
# Train_dice: 0.4674
# 12/0, Train_loss: 0.5317
# Train_dice: 0.4683
# 13/0, Train_loss: 0.5364
# Train_dice: 0.4636
# 14/0, Train_loss: 0.5342
# Train_dice: 0.4658
# --------------------
# Epoch_loss: 0.5341
# Epoch_metric: 0.4659
# test_loss_epoch: 0.5353
# test_dice_epoch: 0.4647
# current epoch: 13 current mean dice: 0.4635
# best mean dice: 0.4647 at epoch: 13
# ----------
# epoch 14/600
# 1/0, Train_loss: 0.5338
# Train_dice: 0.4662
# 2/0, Train_loss: 0.5336
# Train_dice: 0.4664
# 3/0, Train_loss: 0.5350
# Train_dice: 0.4650
# 4/0, Train_loss: 0.5308
# Train_dice: 0.4692
# 5/0, Train_loss: 0.5326
# Train_dice: 0.4674
# 6/0, Train_loss: 0.5349
# Train_dice: 0.4651
# 7/0, Train_loss: 0.5343
# Train_dice: 0.4657
# 8/0, Train_loss: 0.5307
# Train_dice: 0.4693
# 9/0, Train_loss: 0.5355
# Train_dice: 0.4645
# 10/0, Train_loss: 0.5350
# Train_dice: 0.4650
# 11/0, Train_loss: 0.5354
# Train_dice: 0.4646
# 12/0, Train_loss: 0.5319
# Train_dice: 0.4681
# 13/0, Train_loss: 0.5359
# Train_dice: 0.4641
# 14/0, Train_loss: 0.5277
# Train_dice: 0.4723
# --------------------
# Epoch_loss: 0.5334
# Epoch_metric: 0.4666
# test_loss_epoch: 0.5347
# test_dice_epoch: 0.4653
# current epoch: 14 current mean dice: 0.4651
# best mean dice: 0.4653 at epoch: 14
# ----------
# epoch 15/600
# 1/0, Train_loss: 0.5316
# Train_dice: 0.4684
# 2/0, Train_loss: 0.5320
# Train_dice: 0.4680
# 3/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 4/0, Train_loss: 0.5358
# Train_dice: 0.4642
# 5/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 6/0, Train_loss: 0.5345
# Train_dice: 0.4655
# 7/0, Train_loss: 0.5334
# Train_dice: 0.4666
# 8/0, Train_loss: 0.5312
# Train_dice: 0.4688
# 9/0, Train_loss: 0.5313
# Train_dice: 0.4687
# 10/0, Train_loss: 0.5329
# Train_dice: 0.4671
# 11/0, Train_loss: 0.5348
# Train_dice: 0.4652
# 12/0, Train_loss: 0.5356
# Train_dice: 0.4644
# 13/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 14/0, Train_loss: 0.5279
# Train_dice: 0.4721
# --------------------
# Epoch_loss: 0.5329
# Epoch_metric: 0.4671
# test_loss_epoch: 0.5339
# test_dice_epoch: 0.4661
# current epoch: 15 current mean dice: 0.4678
# best mean dice: 0.4661 at epoch: 15
# ----------
# epoch 16/600
# 1/0, Train_loss: 0.5354
# Train_dice: 0.4646
# 2/0, Train_loss: 0.5275
# Train_dice: 0.4725
# 3/0, Train_loss: 0.5342
# Train_dice: 0.4658
# 4/0, Train_loss: 0.5322
# Train_dice: 0.4678
# 5/0, Train_loss: 0.5327
# Train_dice: 0.4673
# 6/0, Train_loss: 0.5321
# Train_dice: 0.4679
# 7/0, Train_loss: 0.5319
# Train_dice: 0.4681
# 8/0, Train_loss: 0.5304
# Train_dice: 0.4696
# 9/0, Train_loss: 0.5350
# Train_dice: 0.4650
# 10/0, Train_loss: 0.5334
# Train_dice: 0.4666
# 11/0, Train_loss: 0.5349
# Train_dice: 0.4651
# 12/0, Train_loss: 0.5311
# Train_dice: 0.4689
# 13/0, Train_loss: 0.5328
# Train_dice: 0.4672
# 14/0, Train_loss: 0.5314
# Train_dice: 0.4686
# --------------------
# Epoch_loss: 0.5325
# Epoch_metric: 0.4675
# test_loss_epoch: 0.5330
# test_dice_epoch: 0.4670
# current epoch: 16 current mean dice: 0.4719
# best mean dice: 0.4670 at epoch: 16
# ----------
# epoch 17/600
# 1/0, Train_loss: 0.5322
# Train_dice: 0.4678
# 2/0, Train_loss: 0.5327
# Train_dice: 0.4673
# 3/0, Train_loss: 0.5307
# Train_dice: 0.4693
# 4/0, Train_loss: 0.5337
# Train_dice: 0.4663
# 5/0, Train_loss: 0.5328
# Train_dice: 0.4672
# 6/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 7/0, Train_loss: 0.5337
# Train_dice: 0.4663
# 8/0, Train_loss: 0.5346
# Train_dice: 0.4654
# 9/0, Train_loss: 0.5335
# Train_dice: 0.4665
# 10/0, Train_loss: 0.5305
# Train_dice: 0.4695
# 11/0, Train_loss: 0.5313
# Train_dice: 0.4687
# 12/0, Train_loss: 0.5318
# Train_dice: 0.4682
# 13/0, Train_loss: 0.5313
# Train_dice: 0.4687
# 14/0, Train_loss: 0.5326
# Train_dice: 0.4674
# --------------------
# Epoch_loss: 0.5321
# Epoch_metric: 0.4679
# test_loss_epoch: 0.5336
# test_dice_epoch: 0.4664
# current epoch: 17 current mean dice: 0.4651
# best mean dice: 0.4670 at epoch: 16
# ----------
# epoch 18/600
# 1/0, Train_loss: 0.5325
# Train_dice: 0.4675
# 2/0, Train_loss: 0.5321
# Train_dice: 0.4679
# 3/0, Train_loss: 0.5342
# Train_dice: 0.4658
# 4/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 5/0, Train_loss: 0.5311
# Train_dice: 0.4689
# 6/0, Train_loss: 0.5333
# Train_dice: 0.4667
# 7/0, Train_loss: 0.5324
# Train_dice: 0.4676
# 8/0, Train_loss: 0.5336
# Train_dice: 0.4664
# 9/0, Train_loss: 0.5293
# Train_dice: 0.4707
# 10/0, Train_loss: 0.5343
# Train_dice: 0.4657
# 11/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 12/0, Train_loss: 0.5341
# Train_dice: 0.4659
# 13/0, Train_loss: 0.5248
# Train_dice: 0.4752
# 14/0, Train_loss: 0.5322
# Train_dice: 0.4678
# --------------------
# Epoch_loss: 0.5316
# Epoch_metric: 0.4684
# test_loss_epoch: 0.5327
# test_dice_epoch: 0.4673
# current epoch: 18 current mean dice: 0.4685
# best mean dice: 0.4673 at epoch: 18
# ----------
# epoch 19/600
# 1/0, Train_loss: 0.5340
# Train_dice: 0.4660
# 2/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 3/0, Train_loss: 0.5310
# Train_dice: 0.4690
# 4/0, Train_loss: 0.5292
# Train_dice: 0.4708
# 5/0, Train_loss: 0.5310
# Train_dice: 0.4690
# 6/0, Train_loss: 0.5333
# Train_dice: 0.4667
# 7/0, Train_loss: 0.5310
# Train_dice: 0.4690
# 8/0, Train_loss: 0.5339
# Train_dice: 0.4661
# 9/0, Train_loss: 0.5297
# Train_dice: 0.4703
# 10/0, Train_loss: 0.5317
# Train_dice: 0.4683
# 11/0, Train_loss: 0.5312
# Train_dice: 0.4688
# 12/0, Train_loss: 0.5293
# Train_dice: 0.4707
# 13/0, Train_loss: 0.5323
# Train_dice: 0.4677
# 14/0, Train_loss: 0.5317
# Train_dice: 0.4683
# --------------------
# Epoch_loss: 0.5312
# Epoch_metric: 0.4688
# test_loss_epoch: 0.5320
# test_dice_epoch: 0.4680
# current epoch: 19 current mean dice: 0.4707
# best mean dice: 0.4680 at epoch: 19
# ----------
# epoch 20/600
# 1/0, Train_loss: 0.5297
# Train_dice: 0.4703
# 2/0, Train_loss: 0.5336
# Train_dice: 0.4664
# 3/0, Train_loss: 0.5268
# Train_dice: 0.4732
# 4/0, Train_loss: 0.5314
# Train_dice: 0.4686
# 5/0, Train_loss: 0.5317
# Train_dice: 0.4683
# 6/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 7/0, Train_loss: 0.5311
# Train_dice: 0.4689
# 8/0, Train_loss: 0.5321
# Train_dice: 0.4679
# 9/0, Train_loss: 0.5325
# Train_dice: 0.4675
# 10/0, Train_loss: 0.5318
# Train_dice: 0.4682
# 11/0, Train_loss: 0.5271
# Train_dice: 0.4729
# 12/0, Train_loss: 0.5323
# Train_dice: 0.4677
# 13/0, Train_loss: 0.5308
# Train_dice: 0.4692
# 14/0, Train_loss: 0.5293
# Train_dice: 0.4707
# --------------------
# Epoch_loss: 0.5307
# Epoch_metric: 0.4693
# test_loss_epoch: 0.5321
# test_dice_epoch: 0.4679
# current epoch: 20 current mean dice: 0.4667
# best mean dice: 0.4680 at epoch: 19
# ----------
# epoch 21/600
# 1/0, Train_loss: 0.5329
# Train_dice: 0.4671
# 2/0, Train_loss: 0.5308
# Train_dice: 0.4692
# 3/0, Train_loss: 0.5322
# Train_dice: 0.4678
# 4/0, Train_loss: 0.5280
# Train_dice: 0.4720
# 5/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 6/0, Train_loss: 0.5331
# Train_dice: 0.4669
# 7/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 8/0, Train_loss: 0.5299
# Train_dice: 0.4701
# 9/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 10/0, Train_loss: 0.5323
# Train_dice: 0.4677
# 11/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 12/0, Train_loss: 0.5324
# Train_dice: 0.4676
# 13/0, Train_loss: 0.5314
# Train_dice: 0.4686
# 14/0, Train_loss: 0.5313
# Train_dice: 0.4687
# --------------------
# Epoch_loss: 0.5304
# Epoch_metric: 0.4696
# test_loss_epoch: 0.5315
# test_dice_epoch: 0.4685
# current epoch: 21 current mean dice: 0.4691
# best mean dice: 0.4685 at epoch: 21
# ----------
# epoch 22/600
# 1/0, Train_loss: 0.5329
# Train_dice: 0.4671
# 2/0, Train_loss: 0.5289
# Train_dice: 0.4711
# 3/0, Train_loss: 0.5317
# Train_dice: 0.4683
# 4/0, Train_loss: 0.5304
# Train_dice: 0.4696
# 5/0, Train_loss: 0.5275
# Train_dice: 0.4725
# 6/0, Train_loss: 0.5316
# Train_dice: 0.4684
# 7/0, Train_loss: 0.5327
# Train_dice: 0.4673
# 8/0, Train_loss: 0.5296
# Train_dice: 0.4704
# 9/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 10/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 11/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 12/0, Train_loss: 0.5273
# Train_dice: 0.4727
# 13/0, Train_loss: 0.5326
# Train_dice: 0.4674
# 14/0, Train_loss: 0.5323
# Train_dice: 0.4677
# --------------------
# Epoch_loss: 0.5301
# Epoch_metric: 0.4699
# test_loss_epoch: 0.5314
# test_dice_epoch: 0.4686
# current epoch: 22 current mean dice: 0.4675
# best mean dice: 0.4686 at epoch: 22
# ----------
# epoch 23/600
# 1/0, Train_loss: 0.5322
# Train_dice: 0.4678
# 2/0, Train_loss: 0.5321
# Train_dice: 0.4679
# 3/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 4/0, Train_loss: 0.5324
# Train_dice: 0.4676
# 5/0, Train_loss: 0.5322
# Train_dice: 0.4678
# 6/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 7/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 8/0, Train_loss: 0.5315
# Train_dice: 0.4685
# 9/0, Train_loss: 0.5290
# Train_dice: 0.4710
# 10/0, Train_loss: 0.5324
# Train_dice: 0.4676
# 11/0, Train_loss: 0.5275
# Train_dice: 0.4725
# 12/0, Train_loss: 0.5277
# Train_dice: 0.4723
# 13/0, Train_loss: 0.5318
# Train_dice: 0.4682
# 14/0, Train_loss: 0.5299
# Train_dice: 0.4701
# --------------------
# Epoch_loss: 0.5296
# Epoch_metric: 0.4704
# test_loss_epoch: 0.5309
# test_dice_epoch: 0.4691
# current epoch: 23 current mean dice: 0.4680
# best mean dice: 0.4691 at epoch: 23
# ----------
# epoch 24/600
# 1/0, Train_loss: 0.5286
# Train_dice: 0.4714
# 2/0, Train_loss: 0.5262
# Train_dice: 0.4738
# 3/0, Train_loss: 0.5321
# Train_dice: 0.4679
# 4/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 5/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 6/0, Train_loss: 0.5298
# Train_dice: 0.4702
# 7/0, Train_loss: 0.5314
# Train_dice: 0.4686
# 8/0, Train_loss: 0.5308
# Train_dice: 0.4692
# 9/0, Train_loss: 0.5319
# Train_dice: 0.4681
# 10/0, Train_loss: 0.5295
# Train_dice: 0.4705
# 11/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 12/0, Train_loss: 0.5287
# Train_dice: 0.4713
# 13/0, Train_loss: 0.5306
# Train_dice: 0.4694
# 14/0, Train_loss: 0.5306
# Train_dice: 0.4694
# --------------------
# Epoch_loss: 0.5293
# Epoch_metric: 0.4707
# test_loss_epoch: 0.5307
# test_dice_epoch: 0.4693
# current epoch: 24 current mean dice: 0.4689
# best mean dice: 0.4693 at epoch: 24
# ----------
# epoch 25/600
# 1/0, Train_loss: 0.5295
# Train_dice: 0.4705
# 2/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 3/0, Train_loss: 0.5306
# Train_dice: 0.4694
# 4/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 5/0, Train_loss: 0.5291
# Train_dice: 0.4709
# 6/0, Train_loss: 0.5271
# Train_dice: 0.4729
# 7/0, Train_loss: 0.5310
# Train_dice: 0.4690
# 8/0, Train_loss: 0.5295
# Train_dice: 0.4705
# 9/0, Train_loss: 0.5295
# Train_dice: 0.4705
# 10/0, Train_loss: 0.5302
# Train_dice: 0.4698
# 11/0, Train_loss: 0.5315
# Train_dice: 0.4685
# 12/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 13/0, Train_loss: 0.5315
# Train_dice: 0.4685
# 14/0, Train_loss: 0.5227
# Train_dice: 0.4773
# --------------------
# Epoch_loss: 0.5287
# Epoch_metric: 0.4713
# test_loss_epoch: 0.5304
# test_dice_epoch: 0.4696
# current epoch: 25 current mean dice: 0.4692
# best mean dice: 0.4696 at epoch: 25
# ----------
# epoch 26/600
# 1/0, Train_loss: 0.5263
# Train_dice: 0.4737
# 2/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 3/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 4/0, Train_loss: 0.5311
# Train_dice: 0.4689
# 5/0, Train_loss: 0.5283
# Train_dice: 0.4717
# 6/0, Train_loss: 0.5306
# Train_dice: 0.4694
# 7/0, Train_loss: 0.5263
# Train_dice: 0.4737
# 8/0, Train_loss: 0.5299
# Train_dice: 0.4701
# 9/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 10/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 11/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 12/0, Train_loss: 0.5269
# Train_dice: 0.4731
# 13/0, Train_loss: 0.5309
# Train_dice: 0.4691
# 14/0, Train_loss: 0.5299
# Train_dice: 0.4701
# --------------------
# Epoch_loss: 0.5286
# Epoch_metric: 0.4714
# test_loss_epoch: 0.5299
# test_dice_epoch: 0.4701
# current epoch: 26 current mean dice: 0.4708
# best mean dice: 0.4701 at epoch: 26
# ----------
# epoch 27/600
# 1/0, Train_loss: 0.5297
# Train_dice: 0.4703
# 2/0, Train_loss: 0.5243
# Train_dice: 0.4757
# 3/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 4/0, Train_loss: 0.5273
# Train_dice: 0.4727
# 5/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 6/0, Train_loss: 0.5298
# Train_dice: 0.4702
# 7/0, Train_loss: 0.5262
# Train_dice: 0.4738
# 8/0, Train_loss: 0.5309
# Train_dice: 0.4691
# 9/0, Train_loss: 0.5269
# Train_dice: 0.4731
# 10/0, Train_loss: 0.5199
# Train_dice: 0.4801
# 11/0, Train_loss: 0.5303
# Train_dice: 0.4697
# 12/0, Train_loss: 0.5309
# Train_dice: 0.4691
# 13/0, Train_loss: 0.5296
# Train_dice: 0.4704
# 14/0, Train_loss: 0.5309
# Train_dice: 0.4691
# --------------------
# Epoch_loss: 0.5283
# Epoch_metric: 0.4717
# test_loss_epoch: 0.5299
# test_dice_epoch: 0.4701
# current epoch: 27 current mean dice: 0.4687
# best mean dice: 0.4701 at epoch: 27
# ----------
# epoch 28/600
# 1/0, Train_loss: 0.5284
# Train_dice: 0.4716
# 2/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 3/0, Train_loss: 0.5284
# Train_dice: 0.4716
# 4/0, Train_loss: 0.5296
# Train_dice: 0.4704
# 5/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 6/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 7/0, Train_loss: 0.5296
# Train_dice: 0.4704
# 8/0, Train_loss: 0.5293
# Train_dice: 0.4707
# 9/0, Train_loss: 0.5292
# Train_dice: 0.4708
# 10/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 11/0, Train_loss: 0.5274
# Train_dice: 0.4726
# 12/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 13/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 14/0, Train_loss: 0.5301
# Train_dice: 0.4699
# --------------------
# Epoch_loss: 0.5280
# Epoch_metric: 0.4720
# test_loss_epoch: 0.5293
# test_dice_epoch: 0.4707
# current epoch: 28 current mean dice: 0.4715
# best mean dice: 0.4707 at epoch: 28
# ----------
# epoch 29/600
# 1/0, Train_loss: 0.5295
# Train_dice: 0.4705
# 2/0, Train_loss: 0.5305
# Train_dice: 0.4695
# 3/0, Train_loss: 0.5294
# Train_dice: 0.4706
# 4/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 5/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 6/0, Train_loss: 0.5294
# Train_dice: 0.4706
# 7/0, Train_loss: 0.5282
# Train_dice: 0.4718
# 8/0, Train_loss: 0.5287
# Train_dice: 0.4713
# 9/0, Train_loss: 0.5225
# Train_dice: 0.4775
# 10/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 11/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 12/0, Train_loss: 0.5303
# Train_dice: 0.4697
# 13/0, Train_loss: 0.5286
# Train_dice: 0.4714
# 14/0, Train_loss: 0.5240
# Train_dice: 0.4760
# --------------------
# Epoch_loss: 0.5276
# Epoch_metric: 0.4724
# test_loss_epoch: 0.5293
# test_dice_epoch: 0.4707
# current epoch: 29 current mean dice: 0.4696
# best mean dice: 0.4707 at epoch: 29
# ----------
# epoch 30/600
# 1/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 2/0, Train_loss: 0.5302
# Train_dice: 0.4698
# 3/0, Train_loss: 0.5288
# Train_dice: 0.4712
# 4/0, Train_loss: 0.5290
# Train_dice: 0.4710
# 5/0, Train_loss: 0.5278
# Train_dice: 0.4722
# 6/0, Train_loss: 0.5223
# Train_dice: 0.4777
# 7/0, Train_loss: 0.5290
# Train_dice: 0.4710
# 8/0, Train_loss: 0.5301
# Train_dice: 0.4699
# 9/0, Train_loss: 0.5300
# Train_dice: 0.4700
# 10/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 11/0, Train_loss: 0.5298
# Train_dice: 0.4702
# 12/0, Train_loss: 0.5235
# Train_dice: 0.4765
# 13/0, Train_loss: 0.5243
# Train_dice: 0.4757
# 14/0, Train_loss: 0.5248
# Train_dice: 0.4752
# --------------------
# Epoch_loss: 0.5273
# Epoch_metric: 0.4727
# test_loss_epoch: 0.5292
# test_dice_epoch: 0.4708
# current epoch: 30 current mean dice: 0.4696
# best mean dice: 0.4708 at epoch: 30
# ----------
# epoch 31/600
# 1/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 2/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 3/0, Train_loss: 0.5297
# Train_dice: 0.4703
# 4/0, Train_loss: 0.5298
# Train_dice: 0.4702
# 5/0, Train_loss: 0.5297
# Train_dice: 0.4703
# 6/0, Train_loss: 0.5286
# Train_dice: 0.4714
# 7/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 8/0, Train_loss: 0.5274
# Train_dice: 0.4726
# 9/0, Train_loss: 0.5280
# Train_dice: 0.4720
# 10/0, Train_loss: 0.5294
# Train_dice: 0.4706
# 11/0, Train_loss: 0.5218
# Train_dice: 0.4782
# 12/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 13/0, Train_loss: 0.5252
# Train_dice: 0.4748
# 14/0, Train_loss: 0.5273
# Train_dice: 0.4727
# --------------------
# Epoch_loss: 0.5271
# Epoch_metric: 0.4729
# test_loss_epoch: 0.5289
# test_dice_epoch: 0.4711
# current epoch: 31 current mean dice: 0.4700
# best mean dice: 0.4711 at epoch: 31
# ----------
# epoch 32/600
# 1/0, Train_loss: 0.5263
# Train_dice: 0.4737
# 2/0, Train_loss: 0.5233
# Train_dice: 0.4767
# 3/0, Train_loss: 0.5274
# Train_dice: 0.4726
# 4/0, Train_loss: 0.5280
# Train_dice: 0.4720
# 5/0, Train_loss: 0.5293
# Train_dice: 0.4707
# 6/0, Train_loss: 0.5294
# Train_dice: 0.4706
# 7/0, Train_loss: 0.5268
# Train_dice: 0.4732
# 8/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 9/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 10/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 11/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 12/0, Train_loss: 0.5262
# Train_dice: 0.4738
# 13/0, Train_loss: 0.5294
# Train_dice: 0.4706
# 14/0, Train_loss: 0.5239
# Train_dice: 0.4761
# --------------------
# Epoch_loss: 0.5267
# Epoch_metric: 0.4733
# test_loss_epoch: 0.5283
# test_dice_epoch: 0.4717
# current epoch: 32 current mean dice: 0.4715
# best mean dice: 0.4717 at epoch: 32
# ----------
# epoch 33/600
# 1/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 2/0, Train_loss: 0.5277
# Train_dice: 0.4723
# 3/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 4/0, Train_loss: 0.5268
# Train_dice: 0.4732
# 5/0, Train_loss: 0.5280
# Train_dice: 0.4720
# 6/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 7/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 8/0, Train_loss: 0.5274
# Train_dice: 0.4726
# 9/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 10/0, Train_loss: 0.5292
# Train_dice: 0.4708
# 11/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 12/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 13/0, Train_loss: 0.5285
# Train_dice: 0.4715
# 14/0, Train_loss: 0.5292
# Train_dice: 0.4708
# --------------------
# Epoch_loss: 0.5266
# Epoch_metric: 0.4734
# test_loss_epoch: 0.5279
# test_dice_epoch: 0.4721
# current epoch: 33 current mean dice: 0.4720
# best mean dice: 0.4721 at epoch: 33
# ----------
# epoch 34/600
# 1/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 2/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 3/0, Train_loss: 0.5265
# Train_dice: 0.4735
# 4/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 5/0, Train_loss: 0.5284
# Train_dice: 0.4716
# 6/0, Train_loss: 0.5278
# Train_dice: 0.4722
# 7/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 8/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 9/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 10/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 11/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 12/0, Train_loss: 0.5273
# Train_dice: 0.4727
# 13/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 14/0, Train_loss: 0.5264
# Train_dice: 0.4736
# --------------------
# Epoch_loss: 0.5263
# Epoch_metric: 0.4737
# test_loss_epoch: 0.5280
# test_dice_epoch: 0.4720
# current epoch: 34 current mean dice: 0.4708
# best mean dice: 0.4721 at epoch: 33
# ----------
# epoch 35/600
# 1/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 2/0, Train_loss: 0.5252
# Train_dice: 0.4748
# 3/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 4/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 5/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 6/0, Train_loss: 0.5232
# Train_dice: 0.4768
# 7/0, Train_loss: 0.5272
# Train_dice: 0.4728
# 8/0, Train_loss: 0.5264
# Train_dice: 0.4736
# 9/0, Train_loss: 0.5286
# Train_dice: 0.4714
# 10/0, Train_loss: 0.5272
# Train_dice: 0.4728
# 11/0, Train_loss: 0.5218
# Train_dice: 0.4782
# 12/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 13/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 14/0, Train_loss: 0.5243
# Train_dice: 0.4757
# --------------------
# Epoch_loss: 0.5260
# Epoch_metric: 0.4740
# test_loss_epoch: 0.5277
# test_dice_epoch: 0.4723
# current epoch: 35 current mean dice: 0.4712
# best mean dice: 0.4723 at epoch: 35
# ----------
# epoch 36/600
# 1/0, Train_loss: 0.5286
# Train_dice: 0.4714
# 2/0, Train_loss: 0.5253
# Train_dice: 0.4747
# 3/0, Train_loss: 0.5245
# Train_dice: 0.4755
# 4/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 5/0, Train_loss: 0.5238
# Train_dice: 0.4762
# 6/0, Train_loss: 0.5284
# Train_dice: 0.4716
# 7/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 8/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 9/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 10/0, Train_loss: 0.5242
# Train_dice: 0.4758
# 11/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 12/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 13/0, Train_loss: 0.5272
# Train_dice: 0.4728
# 14/0, Train_loss: 0.5244
# Train_dice: 0.4756
# --------------------
# Epoch_loss: 0.5257
# Epoch_metric: 0.4743
# test_loss_epoch: 0.5271
# test_dice_epoch: 0.4729
# current epoch: 36 current mean dice: 0.4737
# best mean dice: 0.4729 at epoch: 36
# ----------
# epoch 37/600
# 1/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 2/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 3/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 4/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 5/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 6/0, Train_loss: 0.5283
# Train_dice: 0.4717
# 7/0, Train_loss: 0.5194
# Train_dice: 0.4806
# 8/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 9/0, Train_loss: 0.5279
# Train_dice: 0.4721
# 10/0, Train_loss: 0.5282
# Train_dice: 0.4718
# 11/0, Train_loss: 0.5211
# Train_dice: 0.4789
# 12/0, Train_loss: 0.5275
# Train_dice: 0.4725
# 13/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 14/0, Train_loss: 0.5255
# Train_dice: 0.4745
# --------------------
# Epoch_loss: 0.5255
# Epoch_metric: 0.4745
# test_loss_epoch: 0.5270
# test_dice_epoch: 0.4730
# current epoch: 37 current mean dice: 0.4719
# best mean dice: 0.4730 at epoch: 37
# ----------
# epoch 38/600
# 1/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 2/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 3/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 4/0, Train_loss: 0.5252
# Train_dice: 0.4748
# 5/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 6/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 7/0, Train_loss: 0.5281
# Train_dice: 0.4719
# 8/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 9/0, Train_loss: 0.5281
# Train_dice: 0.4719
# 10/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 11/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 12/0, Train_loss: 0.5229
# Train_dice: 0.4771
# 13/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 14/0, Train_loss: 0.5274
# Train_dice: 0.4726
# --------------------
# Epoch_loss: 0.5254
# Epoch_metric: 0.4746
# test_loss_epoch: 0.5271
# test_dice_epoch: 0.4729
# current epoch: 38 current mean dice: 0.4718
# best mean dice: 0.4730 at epoch: 37
# ----------
# epoch 39/600
# 1/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 2/0, Train_loss: 0.5217
# Train_dice: 0.4783
# 3/0, Train_loss: 0.5253
# Train_dice: 0.4747
# 4/0, Train_loss: 0.5253
# Train_dice: 0.4747
# 5/0, Train_loss: 0.5226
# Train_dice: 0.4774
# 6/0, Train_loss: 0.5224
# Train_dice: 0.4776
# 7/0, Train_loss: 0.5271
# Train_dice: 0.4729
# 8/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 9/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 10/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 11/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 12/0, Train_loss: 0.5221
# Train_dice: 0.4779
# 13/0, Train_loss: 0.5276
# Train_dice: 0.4724
# 14/0, Train_loss: 0.5277
# Train_dice: 0.4723
# --------------------
# Epoch_loss: 0.5252
# Epoch_metric: 0.4748
# test_loss_epoch: 0.5264
# test_dice_epoch: 0.4736
# current epoch: 39 current mean dice: 0.4746
# best mean dice: 0.4736 at epoch: 39
# ----------
# epoch 40/600
# 1/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 2/0, Train_loss: 0.5265
# Train_dice: 0.4735
# 3/0, Train_loss: 0.5277
# Train_dice: 0.4723
# 4/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 5/0, Train_loss: 0.5229
# Train_dice: 0.4771
# 6/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 7/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 8/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 9/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 10/0, Train_loss: 0.5275
# Train_dice: 0.4725
# 11/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 12/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 13/0, Train_loss: 0.5183
# Train_dice: 0.4817
# 14/0, Train_loss: 0.5226
# Train_dice: 0.4774
# --------------------
# Epoch_loss: 0.5248
# Epoch_metric: 0.4752
# test_loss_epoch: 0.5261
# test_dice_epoch: 0.4739
# current epoch: 40 current mean dice: 0.4748
# best mean dice: 0.4739 at epoch: 40
# ----------
# epoch 41/600
# 1/0, Train_loss: 0.5209
# Train_dice: 0.4791
# 2/0, Train_loss: 0.5268
# Train_dice: 0.4732
# 3/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 4/0, Train_loss: 0.5271
# Train_dice: 0.4729
# 5/0, Train_loss: 0.5198
# Train_dice: 0.4802
# 6/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 7/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 8/0, Train_loss: 0.5261
# Train_dice: 0.4739
# 9/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 10/0, Train_loss: 0.5232
# Train_dice: 0.4768
# 11/0, Train_loss: 0.5223
# Train_dice: 0.4777
# 12/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 13/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 14/0, Train_loss: 0.5256
# Train_dice: 0.4744
# --------------------
# Epoch_loss: 0.5247
# Epoch_metric: 0.4753
# test_loss_epoch: 0.5254
# test_dice_epoch: 0.4746
# current epoch: 41 current mean dice: 0.4782
# best mean dice: 0.4746 at epoch: 41
# ----------
# epoch 42/600
# 1/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 2/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 3/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 4/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 5/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 6/0, Train_loss: 0.5235
# Train_dice: 0.4765
# 7/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 8/0, Train_loss: 0.5248
# Train_dice: 0.4752
# 9/0, Train_loss: 0.5236
# Train_dice: 0.4764
# 10/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 11/0, Train_loss: 0.5206
# Train_dice: 0.4794
# 12/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 13/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 14/0, Train_loss: 0.5226
# Train_dice: 0.4774
# --------------------
# Epoch_loss: 0.5244
# Epoch_metric: 0.4756
# test_loss_epoch: 0.5260
# test_dice_epoch: 0.4740
# current epoch: 42 current mean dice: 0.4730
# best mean dice: 0.4746 at epoch: 41
# ----------
# epoch 43/600
# 1/0, Train_loss: 0.5196
# Train_dice: 0.4804
# 2/0, Train_loss: 0.5270
# Train_dice: 0.4730
# 3/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 4/0, Train_loss: 0.5207
# Train_dice: 0.4793
# 5/0, Train_loss: 0.5248
# Train_dice: 0.4752
# 6/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 7/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 8/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 9/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 10/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 11/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 12/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 13/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 14/0, Train_loss: 0.5239
# Train_dice: 0.4761
# --------------------
# Epoch_loss: 0.5242
# Epoch_metric: 0.4758
# test_loss_epoch: 0.5249
# test_dice_epoch: 0.4751
# current epoch: 43 current mean dice: 0.4778
# best mean dice: 0.4751 at epoch: 43
# ----------
# epoch 44/600
# 1/0, Train_loss: 0.5204
# Train_dice: 0.4796
# 2/0, Train_loss: 0.5238
# Train_dice: 0.4762
# 3/0, Train_loss: 0.5228
# Train_dice: 0.4772
# 4/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 5/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 6/0, Train_loss: 0.5268
# Train_dice: 0.4732
# 7/0, Train_loss: 0.5242
# Train_dice: 0.4758
# 8/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 9/0, Train_loss: 0.5266
# Train_dice: 0.4734
# 10/0, Train_loss: 0.5214
# Train_dice: 0.4786
# 11/0, Train_loss: 0.5267
# Train_dice: 0.4733
# 12/0, Train_loss: 0.5258
# Train_dice: 0.4742
# 13/0, Train_loss: 0.5176
# Train_dice: 0.4824
# 14/0, Train_loss: 0.5253
# Train_dice: 0.4747
# --------------------
# Epoch_loss: 0.5240
# Epoch_metric: 0.4760
# test_loss_epoch: 0.5251
# test_dice_epoch: 0.4749
# current epoch: 44 current mean dice: 0.4757
# best mean dice: 0.4751 at epoch: 43
# ----------
# epoch 45/600
# 1/0, Train_loss: 0.5216
# Train_dice: 0.4784
# 2/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 3/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 4/0, Train_loss: 0.5238
# Train_dice: 0.4762
# 5/0, Train_loss: 0.5243
# Train_dice: 0.4757
# 6/0, Train_loss: 0.5253
# Train_dice: 0.4747
# 7/0, Train_loss: 0.5222
# Train_dice: 0.4778
# 8/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 9/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 10/0, Train_loss: 0.5264
# Train_dice: 0.4736
# 11/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 12/0, Train_loss: 0.5209
# Train_dice: 0.4791
# 13/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 14/0, Train_loss: 0.5221
# Train_dice: 0.4779
# --------------------
# Epoch_loss: 0.5237
# Epoch_metric: 0.4763
# test_loss_epoch: 0.5254
# test_dice_epoch: 0.4746
# current epoch: 45 current mean dice: 0.4736
# best mean dice: 0.4751 at epoch: 43
# ----------
# epoch 46/600
# 1/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 2/0, Train_loss: 0.5172
# Train_dice: 0.4828
# 3/0, Train_loss: 0.5264
# Train_dice: 0.4736
# 4/0, Train_loss: 0.5221
# Train_dice: 0.4779
# 5/0, Train_loss: 0.5214
# Train_dice: 0.4786
# 6/0, Train_loss: 0.5198
# Train_dice: 0.4802
# 7/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 8/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 9/0, Train_loss: 0.5263
# Train_dice: 0.4737
# 10/0, Train_loss: 0.5214
# Train_dice: 0.4786
# 11/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 12/0, Train_loss: 0.5262
# Train_dice: 0.4738
# 13/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 14/0, Train_loss: 0.5262
# Train_dice: 0.4738
# --------------------
# Epoch_loss: 0.5237
# Epoch_metric: 0.4763
# test_loss_epoch: 0.5246
# test_dice_epoch: 0.4754
# current epoch: 46 current mean dice: 0.4764
# best mean dice: 0.4754 at epoch: 46
# ----------
# epoch 47/600
# 1/0, Train_loss: 0.5257
# Train_dice: 0.4743
# 2/0, Train_loss: 0.5260
# Train_dice: 0.4740
# 3/0, Train_loss: 0.5217
# Train_dice: 0.4783
# 4/0, Train_loss: 0.5236
# Train_dice: 0.4764
# 5/0, Train_loss: 0.5235
# Train_dice: 0.4765
# 6/0, Train_loss: 0.5188
# Train_dice: 0.4812
# 7/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 8/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 9/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 10/0, Train_loss: 0.5217
# Train_dice: 0.4783
# 11/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 12/0, Train_loss: 0.5210
# Train_dice: 0.4790
# 13/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 14/0, Train_loss: 0.5259
# Train_dice: 0.4741
# --------------------
# Epoch_loss: 0.5235
# Epoch_metric: 0.4765
# test_loss_epoch: 0.5249
# test_dice_epoch: 0.4751
# current epoch: 47 current mean dice: 0.4748
# best mean dice: 0.4754 at epoch: 46
# ----------
# epoch 48/600
# 1/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 2/0, Train_loss: 0.5194
# Train_dice: 0.4806
# 3/0, Train_loss: 0.5215
# Train_dice: 0.4785
# 4/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 5/0, Train_loss: 0.5238
# Train_dice: 0.4762
# 6/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 7/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 8/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 9/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 10/0, Train_loss: 0.5210
# Train_dice: 0.4790
# 11/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 12/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 13/0, Train_loss: 0.5229
# Train_dice: 0.4771
# 14/0, Train_loss: 0.5237
# Train_dice: 0.4763
# --------------------
# Epoch_loss: 0.5232
# Epoch_metric: 0.4768
# test_loss_epoch: 0.5245
# test_dice_epoch: 0.4755
# current epoch: 48 current mean dice: 0.4752
# best mean dice: 0.4755 at epoch: 48
# ----------
# epoch 49/600
# 1/0, Train_loss: 0.5259
# Train_dice: 0.4741
# 2/0, Train_loss: 0.5192
# Train_dice: 0.4808
# 3/0, Train_loss: 0.5245
# Train_dice: 0.4755
# 4/0, Train_loss: 0.5210
# Train_dice: 0.4790
# 5/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 6/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 7/0, Train_loss: 0.5206
# Train_dice: 0.4794
# 8/0, Train_loss: 0.5228
# Train_dice: 0.4772
# 9/0, Train_loss: 0.5240
# Train_dice: 0.4760
# 10/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 11/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 12/0, Train_loss: 0.5238
# Train_dice: 0.4762
# 13/0, Train_loss: 0.5224
# Train_dice: 0.4776
# 14/0, Train_loss: 0.5244
# Train_dice: 0.4756
# --------------------
# Epoch_loss: 0.5230
# Epoch_metric: 0.4770
# test_loss_epoch: 0.5243
# test_dice_epoch: 0.4757
# current epoch: 49 current mean dice: 0.4755
# best mean dice: 0.4757 at epoch: 49
# ----------
# epoch 50/600
# 1/0, Train_loss: 0.5192
# Train_dice: 0.4808
# 2/0, Train_loss: 0.5222
# Train_dice: 0.4778
# 3/0, Train_loss: 0.5223
# Train_dice: 0.4777
# 4/0, Train_loss: 0.5256
# Train_dice: 0.4744
# 5/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 6/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 7/0, Train_loss: 0.5193
# Train_dice: 0.4807
# 8/0, Train_loss: 0.5195
# Train_dice: 0.4805
# 9/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 10/0, Train_loss: 0.5242
# Train_dice: 0.4758
# 11/0, Train_loss: 0.5255
# Train_dice: 0.4745
# 12/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 13/0, Train_loss: 0.5213
# Train_dice: 0.4787
# 14/0, Train_loss: 0.5252
# Train_dice: 0.4748
# --------------------
# Epoch_loss: 0.5229
# Epoch_metric: 0.4771
# test_loss_epoch: 0.5244
# test_dice_epoch: 0.4756
# current epoch: 50 current mean dice: 0.4744
# best mean dice: 0.4757 at epoch: 49
# ----------
# epoch 51/600
# 1/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 2/0, Train_loss: 0.5226
# Train_dice: 0.4774
# 3/0, Train_loss: 0.5228
# Train_dice: 0.4772
# 4/0, Train_loss: 0.5220
# Train_dice: 0.4780
# 5/0, Train_loss: 0.5254
# Train_dice: 0.4746
# 6/0, Train_loss: 0.5243
# Train_dice: 0.4757
# 7/0, Train_loss: 0.5209
# Train_dice: 0.4791
# 8/0, Train_loss: 0.5218
# Train_dice: 0.4782
# 9/0, Train_loss: 0.5197
# Train_dice: 0.4803
# 10/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 11/0, Train_loss: 0.5233
# Train_dice: 0.4767
# 12/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 13/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 14/0, Train_loss: 0.5225
# Train_dice: 0.4775
# --------------------
# Epoch_loss: 0.5226
# Epoch_metric: 0.4774
# test_loss_epoch: 0.5244
# test_dice_epoch: 0.4756
# current epoch: 51 current mean dice: 0.4745
# best mean dice: 0.4757 at epoch: 49
# ----------
# epoch 52/600
# 1/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 2/0, Train_loss: 0.5236
# Train_dice: 0.4764
# 3/0, Train_loss: 0.5226
# Train_dice: 0.4774
# 4/0, Train_loss: 0.5208
# Train_dice: 0.4792
# 5/0, Train_loss: 0.5252
# Train_dice: 0.4748
# 6/0, Train_loss: 0.5170
# Train_dice: 0.4830
# 7/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 8/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 9/0, Train_loss: 0.5221
# Train_dice: 0.4779
# 10/0, Train_loss: 0.5237
# Train_dice: 0.4763
# 11/0, Train_loss: 0.5233
# Train_dice: 0.4767
# 12/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 13/0, Train_loss: 0.5216
# Train_dice: 0.4784
# 14/0, Train_loss: 0.5215
# Train_dice: 0.4785
# --------------------
# Epoch_loss: 0.5224
# Epoch_metric: 0.4776
# test_loss_epoch: 0.5232
# test_dice_epoch: 0.4768
# current epoch: 52 current mean dice: 0.4794
# best mean dice: 0.4768 at epoch: 52
# ----------
# epoch 53/600
# 1/0, Train_loss: 0.5228
# Train_dice: 0.4772
# 2/0, Train_loss: 0.5171
# Train_dice: 0.4829
# 3/0, Train_loss: 0.5209
# Train_dice: 0.4791
# 4/0, Train_loss: 0.5251
# Train_dice: 0.4749
# 5/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 6/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 7/0, Train_loss: 0.5224
# Train_dice: 0.4776
# 8/0, Train_loss: 0.5182
# Train_dice: 0.4818
# 9/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 10/0, Train_loss: 0.5250
# Train_dice: 0.4750
# 11/0, Train_loss: 0.5216
# Train_dice: 0.4784
# 12/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 13/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 14/0, Train_loss: 0.5208
# Train_dice: 0.4792
# --------------------
# Epoch_loss: 0.5223
# Epoch_metric: 0.4777
# test_loss_epoch: 0.5237
# test_dice_epoch: 0.4763
# current epoch: 53 current mean dice: 0.4752
# best mean dice: 0.4768 at epoch: 52
# ----------
# epoch 54/600
# 1/0, Train_loss: 0.5245
# Train_dice: 0.4755
# 2/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 3/0, Train_loss: 0.5179
# Train_dice: 0.4821
# 4/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 5/0, Train_loss: 0.5249
# Train_dice: 0.4751
# 6/0, Train_loss: 0.5211
# Train_dice: 0.4789
# 7/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 8/0, Train_loss: 0.5235
# Train_dice: 0.4765
# 9/0, Train_loss: 0.5241
# Train_dice: 0.4759
# 10/0, Train_loss: 0.5226
# Train_dice: 0.4774
# 11/0, Train_loss: 0.5204
# Train_dice: 0.4796
# 12/0, Train_loss: 0.5189
# Train_dice: 0.4811
# 13/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 14/0, Train_loss: 0.5196
# Train_dice: 0.4804
# --------------------
# Epoch_loss: 0.5221
# Epoch_metric: 0.4779
# test_loss_epoch: 0.5234
# test_dice_epoch: 0.4766
# current epoch: 54 current mean dice: 0.4775
# best mean dice: 0.4768 at epoch: 52
# ----------
# epoch 55/600
# 1/0, Train_loss: 0.5242
# Train_dice: 0.4758
# 2/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 3/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 4/0, Train_loss: 0.5216
# Train_dice: 0.4784
# 5/0, Train_loss: 0.5247
# Train_dice: 0.4753
# 6/0, Train_loss: 0.5195
# Train_dice: 0.4805
# 7/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 8/0, Train_loss: 0.5223
# Train_dice: 0.4777
# 9/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 10/0, Train_loss: 0.5213
# Train_dice: 0.4787
# 11/0, Train_loss: 0.5201
# Train_dice: 0.4799
# 12/0, Train_loss: 0.5246
# Train_dice: 0.4754
# 13/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 14/0, Train_loss: 0.5159
# Train_dice: 0.4841
# --------------------
# Epoch_loss: 0.5218
# Epoch_metric: 0.4782
# test_loss_epoch: 0.5235
# test_dice_epoch: 0.4765
# current epoch: 55 current mean dice: 0.4763
# best mean dice: 0.4768 at epoch: 52
# ----------
# epoch 56/600
# 1/0, Train_loss: 0.5211
# Train_dice: 0.4789
# 2/0, Train_loss: 0.5221
# Train_dice: 0.4779
# 3/0, Train_loss: 0.5217
# Train_dice: 0.4783
# 4/0, Train_loss: 0.5224
# Train_dice: 0.4776
# 5/0, Train_loss: 0.5136
# Train_dice: 0.4864
# 6/0, Train_loss: 0.5232
# Train_dice: 0.4768
# 7/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 8/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 9/0, Train_loss: 0.5234
# Train_dice: 0.4766
# 10/0, Train_loss: 0.5229
# Train_dice: 0.4771
# 11/0, Train_loss: 0.5228
# Train_dice: 0.4772
# 12/0, Train_loss: 0.5211
# Train_dice: 0.4789
# 13/0, Train_loss: 0.5212
# Train_dice: 0.4788
# 14/0, Train_loss: 0.5242
# Train_dice: 0.4758
# --------------------
# Epoch_loss: 0.5219
# Epoch_metric: 0.4781
# test_loss_epoch: 0.5229
# test_dice_epoch: 0.4771
# current epoch: 56 current mean dice: 0.4781
# best mean dice: 0.4771 at epoch: 56
# ----------
# epoch 57/600
# 1/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 2/0, Train_loss: 0.5201
# Train_dice: 0.4799
# 3/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 4/0, Train_loss: 0.5221
# Train_dice: 0.4779
# 5/0, Train_loss: 0.5197
# Train_dice: 0.4803
# 6/0, Train_loss: 0.5244
# Train_dice: 0.4756
# 7/0, Train_loss: 0.5179
# Train_dice: 0.4821
# 8/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 9/0, Train_loss: 0.5198
# Train_dice: 0.4802
# 10/0, Train_loss: 0.5211
# Train_dice: 0.4789
# 11/0, Train_loss: 0.5193
# Train_dice: 0.4807
# 12/0, Train_loss: 0.5242
# Train_dice: 0.4758
# 13/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 14/0, Train_loss: 0.5215
# Train_dice: 0.4785
# --------------------
# Epoch_loss: 0.5216
# Epoch_metric: 0.4784
# test_loss_epoch: 0.5223
# test_dice_epoch: 0.4777
# current epoch: 57 current mean dice: 0.4824
# best mean dice: 0.4777 at epoch: 57
# ----------
# epoch 58/600
# 1/0, Train_loss: 0.5227
# Train_dice: 0.4773
# 2/0, Train_loss: 0.5210
# Train_dice: 0.4790
# 3/0, Train_loss: 0.5208
# Train_dice: 0.4792
# 4/0, Train_loss: 0.5232
# Train_dice: 0.4768
# 5/0, Train_loss: 0.5217
# Train_dice: 0.4783
# 6/0, Train_loss: 0.5190
# Train_dice: 0.4810
# 7/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 8/0, Train_loss: 0.5219
# Train_dice: 0.4781
# 9/0, Train_loss: 0.5226
# Train_dice: 0.4774
# 10/0, Train_loss: 0.5213
# Train_dice: 0.4787
# 11/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 12/0, Train_loss: 0.5191
# Train_dice: 0.4809
# 13/0, Train_loss: 0.5195
# Train_dice: 0.4805
# 14/0, Train_loss: 0.5241
# Train_dice: 0.4759
# --------------------
# Epoch_loss: 0.5216
# Epoch_metric: 0.4784
# test_loss_epoch: 0.5228
# test_dice_epoch: 0.4772
# current epoch: 58 current mean dice: 0.4783
# best mean dice: 0.4777 at epoch: 57
# ----------
# epoch 59/600
# 1/0, Train_loss: 0.5198
# Train_dice: 0.4802
# 2/0, Train_loss: 0.5230
# Train_dice: 0.4770
# 3/0, Train_loss: 0.5240
# Train_dice: 0.4760
# 4/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 5/0, Train_loss: 0.5231
# Train_dice: 0.4769
# 6/0, Train_loss: 0.5176
# Train_dice: 0.4824
# 7/0, Train_loss: 0.5125
# Train_dice: 0.4875
# 8/0, Train_loss: 0.5239
# Train_dice: 0.4761
# 9/0, Train_loss: 0.5218
# Train_dice: 0.4782
# 10/0, Train_loss: 0.5225
# Train_dice: 0.4775
# ...
# Train_dice: 0.5377
# 13/0, Train_loss: 0.4753
# Train_dice: 0.5247
# 14/0, Train_loss: 0.5029
# Train_dice: 0.4971
# --------------------
# Epoch_loss: 0.4722
# Epoch_metric: 0.5278
# test_loss_epoch: 0.4827
# test_dice_epoch: 0.5173
# current epoch: 581 current mean dice: 0.5494
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 582/600
# 1/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 2/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 3/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 4/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 5/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 6/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 7/0, Train_loss: 0.4748
# Train_dice: 0.5252
# 8/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 9/0, Train_loss: 0.4356
# Train_dice: 0.5644
# 10/0, Train_loss: 0.4481
# Train_dice: 0.5519
# 11/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 12/0, Train_loss: 0.4755
# Train_dice: 0.5245
# 13/0, Train_loss: 0.4607
# Train_dice: 0.5393
# 14/0, Train_loss: 0.4374
# Train_dice: 0.5626
# --------------------
# Epoch_loss: 0.4703
# Epoch_metric: 0.5297
# test_loss_epoch: 0.4861
# test_dice_epoch: 0.5139
# current epoch: 582 current mean dice: 0.5315
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 583/600
# 1/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 2/0, Train_loss: 0.4622
# Train_dice: 0.5378
# 3/0, Train_loss: 0.4231
# Train_dice: 0.5769
# 4/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 5/0, Train_loss: 0.4889
# Train_dice: 0.5111
# 6/0, Train_loss: 0.4603
# Train_dice: 0.5397
# 7/0, Train_loss: 0.4600
# Train_dice: 0.5400
# 8/0, Train_loss: 0.4614
# Train_dice: 0.5386
# 9/0, Train_loss: 0.4750
# Train_dice: 0.5250
# 10/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 11/0, Train_loss: 0.4487
# Train_dice: 0.5513
# 12/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 13/0, Train_loss: 0.4748
# Train_dice: 0.5252
# 14/0, Train_loss: 0.5029
# Train_dice: 0.4971
# --------------------
# Epoch_loss: 0.4722
# Epoch_metric: 0.5278
# test_loss_epoch: 0.4885
# test_dice_epoch: 0.5115
# current epoch: 583 current mean dice: 0.5114
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 584/600
# 1/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 2/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 3/0, Train_loss: 0.4480
# Train_dice: 0.5520
# 4/0, Train_loss: 0.4621
# Train_dice: 0.5379
# 5/0, Train_loss: 0.4604
# Train_dice: 0.5396
# 6/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 7/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 8/0, Train_loss: 0.4744
# Train_dice: 0.5256
# 9/0, Train_loss: 0.4499
# Train_dice: 0.5501
# 10/0, Train_loss: 0.4740
# Train_dice: 0.5260
# 11/0, Train_loss: 0.4473
# Train_dice: 0.5527
# 12/0, Train_loss: 0.4495
# Train_dice: 0.5505
# 13/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 14/0, Train_loss: 0.5028
# Train_dice: 0.4972
# --------------------
# Epoch_loss: 0.4722
# Epoch_metric: 0.5278
# test_loss_epoch: 0.4910
# test_dice_epoch: 0.5090
# current epoch: 584 current mean dice: 0.4949
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 585/600
# 1/0, Train_loss: 0.4622
# Train_dice: 0.5378
# 2/0, Train_loss: 0.4751
# Train_dice: 0.5249
# 3/0, Train_loss: 0.4614
# Train_dice: 0.5386
# 4/0, Train_loss: 0.4894
# Train_dice: 0.5106
# 5/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 6/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 7/0, Train_loss: 0.4747
# Train_dice: 0.5253
# 8/0, Train_loss: 0.4628
# Train_dice: 0.5372
# 9/0, Train_loss: 0.4467
# Train_dice: 0.5533
# 10/0, Train_loss: 0.4882
# Train_dice: 0.5118
# 11/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 12/0, Train_loss: 0.4601
# Train_dice: 0.5399
# 13/0, Train_loss: 0.4744
# Train_dice: 0.5256
# 14/0, Train_loss: 0.4328
# Train_dice: 0.5672
# --------------------
# Epoch_loss: 0.4699
# Epoch_metric: 0.5301
# test_loss_epoch: 0.4909
# test_dice_epoch: 0.5091
# current epoch: 585 current mean dice: 0.4948
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 586/600
# 1/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 2/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 3/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 4/0, Train_loss: 0.4758
# Train_dice: 0.5242
# 5/0, Train_loss: 0.4613
# Train_dice: 0.5387
# 6/0, Train_loss: 0.4483
# Train_dice: 0.5517
# 7/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 8/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 9/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 10/0, Train_loss: 0.4606
# Train_dice: 0.5394
# 11/0, Train_loss: 0.4354
# Train_dice: 0.5646
# 12/0, Train_loss: 0.4881
# Train_dice: 0.5119
# 13/0, Train_loss: 0.4757
# Train_dice: 0.5243
# 14/0, Train_loss: 0.4573
# Train_dice: 0.5427
# --------------------
# Epoch_loss: 0.4708
# Epoch_metric: 0.5292
# test_loss_epoch: 0.4884
# test_dice_epoch: 0.5116
# current epoch: 586 current mean dice: 0.5119
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 587/600
# 1/0, Train_loss: 0.4609
# Train_dice: 0.5391
# 2/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 3/0, Train_loss: 0.4890
# Train_dice: 0.5110
# 4/0, Train_loss: 0.4881
# Train_dice: 0.5119
# 5/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 6/0, Train_loss: 0.4603
# Train_dice: 0.5397
# 7/0, Train_loss: 0.4476
# Train_dice: 0.5524
# 8/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 9/0, Train_loss: 0.4898
# Train_dice: 0.5102
# 10/0, Train_loss: 0.4491
# Train_dice: 0.5509
# 11/0, Train_loss: 0.4750
# Train_dice: 0.5250
# 12/0, Train_loss: 0.4609
# Train_dice: 0.5391
# 13/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 14/0, Train_loss: 0.4348
# Train_dice: 0.5652
# --------------------
# Epoch_loss: 0.4701
# Epoch_metric: 0.5299
# test_loss_epoch: 0.4913
# test_dice_epoch: 0.5087
# current epoch: 587 current mean dice: 0.4946
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 588/600
# 1/0, Train_loss: 0.4890
# Train_dice: 0.5110
# 2/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 3/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 4/0, Train_loss: 0.4257
# Train_dice: 0.5743
# 5/0, Train_loss: 0.4622
# Train_dice: 0.5378
# 6/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 7/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 8/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 9/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 10/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 11/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 12/0, Train_loss: 0.4618
# Train_dice: 0.5382
# 13/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 14/0, Train_loss: 0.4154
# Train_dice: 0.5846
# --------------------
# Epoch_loss: 0.4700
# Epoch_metric: 0.5300
# test_loss_epoch: 0.4864
# test_dice_epoch: 0.5136
# current epoch: 588 current mean dice: 0.5267
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 589/600
# 1/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 2/0, Train_loss: 0.4370
# Train_dice: 0.5630
# 3/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 4/0, Train_loss: 0.4752
# Train_dice: 0.5248
# 5/0, Train_loss: 0.4748
# Train_dice: 0.5252
# 6/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 7/0, Train_loss: 0.4605
# Train_dice: 0.5395
# 8/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 9/0, Train_loss: 0.4890
# Train_dice: 0.5110
# 10/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 11/0, Train_loss: 0.4744
# Train_dice: 0.5256
# 12/0, Train_loss: 0.4354
# Train_dice: 0.5646
# 13/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 14/0, Train_loss: 0.4566
# Train_dice: 0.5434
# --------------------
# Epoch_loss: 0.4708
# Epoch_metric: 0.5292
# test_loss_epoch: 0.4863
# test_dice_epoch: 0.5137
# current epoch: 589 current mean dice: 0.5268
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 590/600
# 1/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 2/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 3/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 4/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 5/0, Train_loss: 0.4616
# Train_dice: 0.5384
# 6/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 7/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 8/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 9/0, Train_loss: 0.4487
# Train_dice: 0.5513
# 10/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 11/0, Train_loss: 0.4477
# Train_dice: 0.5523
# 12/0, Train_loss: 0.4753
# Train_dice: 0.5247
# 13/0, Train_loss: 0.4744
# Train_dice: 0.5256
# 14/0, Train_loss: 0.4404
# Train_dice: 0.5596
# --------------------
# Epoch_loss: 0.4703
# Epoch_metric: 0.5297
# test_loss_epoch: 0.4914
# test_dice_epoch: 0.5086
# current epoch: 590 current mean dice: 0.4945
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 591/600
# 1/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 2/0, Train_loss: 0.4611
# Train_dice: 0.5389
# 3/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 4/0, Train_loss: 0.4467
# Train_dice: 0.5533
# 5/0, Train_loss: 0.4482
# Train_dice: 0.5518
# 6/0, Train_loss: 0.4469
# Train_dice: 0.5531
# 7/0, Train_loss: 0.4750
# Train_dice: 0.5250
# 8/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 9/0, Train_loss: 0.4886
# Train_dice: 0.5114
# 10/0, Train_loss: 0.4528
# Train_dice: 0.5472
# 11/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 12/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 13/0, Train_loss: 0.4747
# Train_dice: 0.5253
# 14/0, Train_loss: 0.4788
# Train_dice: 0.5212
# --------------------
# Epoch_loss: 0.4715
# Epoch_metric: 0.5285
# test_loss_epoch: 0.4852
# test_dice_epoch: 0.5148
# current epoch: 591 current mean dice: 0.5320
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 592/600
# 1/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 2/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 3/0, Train_loss: 0.4485
# Train_dice: 0.5515
# 4/0, Train_loss: 0.4622
# Train_dice: 0.5378
# 5/0, Train_loss: 0.4896
# Train_dice: 0.5104
# 6/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 7/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 8/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 9/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 10/0, Train_loss: 0.4477
# Train_dice: 0.5523
# 11/0, Train_loss: 0.4625
# Train_dice: 0.5375
# 12/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 13/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 14/0, Train_loss: 0.4789
# Train_dice: 0.5211
# --------------------
# Epoch_loss: 0.4713
# Epoch_metric: 0.5287
# test_loss_epoch: 0.4856
# test_dice_epoch: 0.5144
# current epoch: 592 current mean dice: 0.5319
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 593/600
# 1/0, Train_loss: 0.4610
# Train_dice: 0.5390
# 2/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 3/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 4/0, Train_loss: 0.4626
# Train_dice: 0.5374
# 5/0, Train_loss: 0.4617
# Train_dice: 0.5383
# 6/0, Train_loss: 0.4744
# Train_dice: 0.5256
# 7/0, Train_loss: 0.4613
# Train_dice: 0.5387
# 8/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 9/0, Train_loss: 0.4470
# Train_dice: 0.5530
# 10/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 11/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 12/0, Train_loss: 0.4892
# Train_dice: 0.5108
# 13/0, Train_loss: 0.4229
# Train_dice: 0.5771
# 14/0, Train_loss: 0.4813
# Train_dice: 0.5187
# --------------------
# Epoch_loss: 0.4717
# Epoch_metric: 0.5283
# test_loss_epoch: 0.4909
# test_dice_epoch: 0.5091
# current epoch: 593 current mean dice: 0.4950
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 594/600
# 1/0, Train_loss: 0.4886
# Train_dice: 0.5114
# 2/0, Train_loss: 0.4478
# Train_dice: 0.5522
# 3/0, Train_loss: 0.4486
# Train_dice: 0.5514
# 4/0, Train_loss: 0.4885
# Train_dice: 0.5115
# 5/0, Train_loss: 0.4626
# Train_dice: 0.5374
# 6/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 7/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 8/0, Train_loss: 0.4617
# Train_dice: 0.5383
# 9/0, Train_loss: 0.4486
# Train_dice: 0.5514
# 10/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 11/0, Train_loss: 0.4888
# Train_dice: 0.5112
# 12/0, Train_loss: 0.4751
# Train_dice: 0.5249
# 13/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 14/0, Train_loss: 0.4786
# Train_dice: 0.5214
# --------------------
# Epoch_loss: 0.4714
# Epoch_metric: 0.5286
# test_loss_epoch: 0.4850
# test_dice_epoch: 0.5150
# current epoch: 594 current mean dice: 0.5322
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 595/600
# 1/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 2/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 3/0, Train_loss: 0.4343
# Train_dice: 0.5657
# 4/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 5/0, Train_loss: 0.4746
# Train_dice: 0.5254
# 6/0, Train_loss: 0.4388
# Train_dice: 0.5612
# 7/0, Train_loss: 0.4614
# Train_dice: 0.5386
# 8/0, Train_loss: 0.4743
# Train_dice: 0.5257
# 9/0, Train_loss: 0.5024
# Train_dice: 0.4976
# 10/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 11/0, Train_loss: 0.4479
# Train_dice: 0.5521
# 12/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 13/0, Train_loss: 0.4617
# Train_dice: 0.5383
# 14/0, Train_loss: 0.4550
# Train_dice: 0.5450
# --------------------
# Epoch_loss: 0.4709
# Epoch_metric: 0.5291
# test_loss_epoch: 0.4906
# test_dice_epoch: 0.5094
# current epoch: 595 current mean dice: 0.4950
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 596/600
# 1/0, Train_loss: 0.4364
# Train_dice: 0.5636
# 2/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 3/0, Train_loss: 0.4215
# Train_dice: 0.5785
# 4/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 5/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 6/0, Train_loss: 0.4609
# Train_dice: 0.5391
# 7/0, Train_loss: 0.4752
# Train_dice: 0.5248
# 8/0, Train_loss: 0.4367
# Train_dice: 0.5633
# 9/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 10/0, Train_loss: 0.4886
# Train_dice: 0.5114
# 11/0, Train_loss: 0.4344
# Train_dice: 0.5656
# 12/0, Train_loss: 0.4884
# Train_dice: 0.5116
# 13/0, Train_loss: 0.5028
# Train_dice: 0.4972
# 14/0, Train_loss: 0.4786
# Train_dice: 0.5214
# --------------------
# Epoch_loss: 0.4718
# Epoch_metric: 0.5282
# test_loss_epoch: 0.4906
# test_dice_epoch: 0.5094
# current epoch: 596 current mean dice: 0.4952
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 597/600
# 1/0, Train_loss: 0.4611
# Train_dice: 0.5389
# 2/0, Train_loss: 0.4745
# Train_dice: 0.5255
# 3/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 4/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 5/0, Train_loss: 0.4490
# Train_dice: 0.5510
# 6/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 7/0, Train_loss: 0.4886
# Train_dice: 0.5114
# 8/0, Train_loss: 0.5027
# Train_dice: 0.4973
# 9/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 10/0, Train_loss: 0.4762
# Train_dice: 0.5238
# 11/0, Train_loss: 0.4742
# Train_dice: 0.5258
# 12/0, Train_loss: 0.4740
# Train_dice: 0.5260
# 13/0, Train_loss: 0.4611
# Train_dice: 0.5389
# 14/0, Train_loss: 0.4566
# Train_dice: 0.5434
# --------------------
# Epoch_loss: 0.4705
# Epoch_metric: 0.5295
# test_loss_epoch: 0.4908
# test_dice_epoch: 0.5092
# current epoch: 597 current mean dice: 0.4951
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 598/600
# 1/0, Train_loss: 0.4476
# Train_dice: 0.5524
# 2/0, Train_loss: 0.5025
# Train_dice: 0.4975
# 3/0, Train_loss: 0.4745
# Train_dice: 0.5255
# 4/0, Train_loss: 0.4749
# Train_dice: 0.5251
# 5/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 6/0, Train_loss: 0.4474
# Train_dice: 0.5526
# 7/0, Train_loss: 0.5026
# Train_dice: 0.4974
# 8/0, Train_loss: 0.5027
# Train_dice: 0.4973
# 9/0, Train_loss: 0.4602
# Train_dice: 0.5398
# 10/0, Train_loss: 0.4471
# Train_dice: 0.5529
# 11/0, Train_loss: 0.4236
# Train_dice: 0.5764
# 12/0, Train_loss: 0.5026
# Train_dice: 0.4974
# 13/0, Train_loss: 0.4624
# Train_dice: 0.5376
# 14/0, Train_loss: 0.4549
# Train_dice: 0.5451
# --------------------
# Epoch_loss: 0.4708
# Epoch_metric: 0.5292
# test_loss_epoch: 0.4883
# test_dice_epoch: 0.5117
# current epoch: 598 current mean dice: 0.5123
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 599/600
# 1/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 2/0, Train_loss: 0.4601
# Train_dice: 0.5399
# 3/0, Train_loss: 0.5027
# Train_dice: 0.4973
# 4/0, Train_loss: 0.4748
# Train_dice: 0.5252
# 5/0, Train_loss: 0.4891
# Train_dice: 0.5109
# 6/0, Train_loss: 0.4882
# Train_dice: 0.5118
# 7/0, Train_loss: 0.4739
# Train_dice: 0.5261
# 8/0, Train_loss: 0.4604
# Train_dice: 0.5396
# 9/0, Train_loss: 0.4741
# Train_dice: 0.5259
# 10/0, Train_loss: 0.4882
# Train_dice: 0.5118
# 11/0, Train_loss: 0.4246
# Train_dice: 0.5754
# 12/0, Train_loss: 0.4348
# Train_dice: 0.5652
# 13/0, Train_loss: 0.4747
# Train_dice: 0.5253
# 14/0, Train_loss: 0.4796
# Train_dice: 0.5204
# --------------------
# Epoch_loss: 0.4714
# Epoch_metric: 0.5286
# test_loss_epoch: 0.4856
# test_dice_epoch: 0.5144
# current epoch: 599 current mean dice: 0.5318
# best mean dice: 0.5199 at epoch: 550
# ----------
# epoch 600/600
# 1/0, Train_loss: 0.4616
# Train_dice: 0.5384
# 2/0, Train_loss: 0.4883
# Train_dice: 0.5117
# 3/0, Train_loss: 0.4880
# Train_dice: 0.5120
# 4/0, Train_loss: 0.5027
# Train_dice: 0.4973
# 5/0, Train_loss: 0.4609
# Train_dice: 0.5391
# 6/0, Train_loss: 0.4750
# Train_dice: 0.5250
# 7/0, Train_loss: 0.4356
# Train_dice: 0.5644
# 8/0, Train_loss: 0.4618
# Train_dice: 0.5382
# 9/0, Train_loss: 0.4599
# Train_dice: 0.5401
# 10/0, Train_loss: 0.5027
# Train_dice: 0.4973
# 11/0, Train_loss: 0.4601
# Train_dice: 0.5399
# 12/0, Train_loss: 0.4882
# Train_dice: 0.5118
# 13/0, Train_loss: 0.4347
# Train_dice: 0.5653
# 14/0, Train_loss: 0.4785
# Train_dice: 0.5215
# --------------------
# Epoch_loss: 0.4713
# Epoch_metric: 0.5287
# test_loss_epoch: 0.4838
# test_dice_epoch: 0.5162
# current epoch: 600 current mean dice: 0.5432
# best mean dice: 0.5199 at epoch: 550
# train completed, best_metric: 0.5199 at epoch: 550

# %% [markdown]
# !ls /kaggle/working/

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.losses import DiceLoss, DiceCELoss

import torch
# from preporcess import prepare
# from utilities import train


# data_dir = 'D:/Youtube/Organ and Tumor Segmentation/datasets/Task03_Liver/Data_Train_Test'
# data_dir = 'D:/Aayush Dataset/nifti_files'
# model_dir = 'D:/Youtube/Organ and Tumor Segmentation/results/results' 
model_dir = '/kaggle/working/results'
# data_in = prepare(data_dir, cache=True)

device = torch.device("cuda:0")
# device = torch.device("cpu")
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256), 
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)


#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)


train(model, data_in, loss_function, optimizer, 600, model_dir)

# %%
# !ls /kaggle/working/
# Out:
# state.db

# %%
# !mkdir results

# %%
# !ls
# Out:
# results  state.db

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# 1. Define a basic custom dataset
class RandomDataset(Dataset):
    def __init__(self, num_samples=1000, input_size=10):
        self.num_samples = num_samples
        self.input_size = input_size
        self.data = torch.randn(num_samples, input_size)  # Random features
        self.labels = torch.randint(0, 2, (num_samples,))  # Binary labels

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# 2. Create dataset and trainloader
dataset = RandomDataset(num_samples=500, input_size=8)
trainloader = DataLoader(dataset, batch_size=32, shuffle=True)

# 3. Sample usage
for batch_data, batch_labels in trainloader:
    print(f"Data batch shape: {batch_data.shape}")
    print(f"Label batch shape: {batch_labels.shape}")
    break  # Just show one batch
# Out:
# Data batch shape: torch.Size([32, 8])
# Label batch shape: torch.Size([32])

# %%
import torch
import pickle

# Assuming your dataset is custom or from torchvision
train_dataset = trainloader.dataset

# Save dataset to a file
with open("train_dataset.pkl", "wb") as f:
    pickle.dump(train_dataset, f)

# %%
with open("train_dataset.pkl", "rb") as f:
    train_dataset = pickle.load(f)

trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
# 3. Sample usage
for batch_data, batch_labels in trainloader:
    print(f"Data batch shape: {batch_data.shape}")
    print(f"Label batch shape: {batch_labels.shape}")
    break  # Just show one batch
# Out:
# Data batch shape: torch.Size([32, 8])
# Label batch shape: torch.Size([32])
